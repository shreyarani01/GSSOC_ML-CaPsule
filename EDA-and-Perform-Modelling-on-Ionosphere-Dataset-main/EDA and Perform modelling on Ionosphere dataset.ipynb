# %% [markdown]
# # Project Description:
# The following project aims to predict class using various technical specifications (features) as input to the logistic regression algorithms.

# %% [markdown]
# # Importing the required libraries

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /opt/anaconda3/lib/python3.13/site-packages (3.3.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from xgboost) (2.5.1)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.13/site-packages (from xgboost) (1.18.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %% [markdown]
# # Loading Data and Dataset Understanding

# %%
data=pd.read_csv(r'Ionosphere.csv')
data.head()
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10  ...      V26      V27      V28      V29      V30      V31  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#        V32      V33      V34  Class
# 0 -0.54487  0.18641 -0.45300      1
# 1 -0.06288 -0.13738 -0.02447      0
# 2 -0.24180  0.56045 -0.38238      1
# 3  1.00000 -0.32382  1.00000      0
# 4 -0.59573 -0.04608 -0.65697      1
#
# [5 rows x 35 columns]

# %%
data.ndim         #dimension of dataset
# Out:
# 2

# %%
data.columns #columns of dataset
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31',
#        'V32', 'V33', 'V34', 'Class'],
#       dtype='object')

# %%
data.dtypes   #datatype of dataset
# Out:
# V1         int64
# V2         int64
# V3       float64
# V4       float64
# V5       float64
# V6       float64
# V7       float64
# V8       float64
# V9       float64
# V10      float64
# V11      float64
# V12      float64
# V13      float64
# V14      float64
# V15      float64
# V16      float64
# V17      float64
# V18      float64
# V19      float64
# V20      float64
# V21      float64
# V22      float64
# V23      float64
# V24      float64
# V25      float64
# V26      float64
# V27      float64
# V28      float64
# V29      float64
# V30      float64
# V31      float64
# V32      float64
# V33      float64
# V34      float64
# Class      int64
# dtype: object

# %%
data['V2'].value_counts()
# Out:
# V2
# 0    351
# Name: count, dtype: int64

# %%
data['V1'].value_counts()
# Out:
# V1
# 1    313
# 0     38
# Name: count, dtype: int64

# %%
data.drop('V2',axis=1,inplace=True)

# %%
data.shape   #shape of dataset
# Out:
# (351, 34)

# %%
data.info()        #basic information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 34 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      351 non-null    int64
#  1   V3      351 non-null    float64
#  2   V4      351 non-null    float64
#  3   V5      351 non-null    float64
#  4   V6      351 non-null    float64
#  5   V7      351 non-null    float64
#  6   V8      351 non-null    float64
#  7   V9      351 non-null    float64
#  8   V10     351 non-null    float64
#  9   V11     351 non-null    float64
#  10  V12     351 non-null    float64
#  11  V13     351 non-null    float64
#  12  V14     351 non-null    float64
#  13  V15     351 non-null    float64
#  14  V16     351 non-null    float64
#  15  V17     351 non-null    float64
#  16  V18     351 non-null    float64
#  17  V19     351 non-null    float64
#  18  V20     351 non-null    float64
#  19  V21     351 non-null    float64
#  20  V22     351 non-null    float64
#  21  V23     351 non-null    float64
#  22  V24     351 non-null    float64
#  23  V25     351 non-null    float64
#  24  V26     351 non-null    float64
#  25  V27     351 non-null    float64
#  26  V28     351 non-null    float64
#  27  V29     351 non-null    float64
#  28  V30     351 non-null    float64
#  29  V31     351 non-null    float64
#  30  V32     351 non-null    float64
#  31  V33     351 non-null    float64
#  32  V34     351 non-null    float64
#  33  Class   351 non-null    int64
# dtypes: float64(32), int64(2)
# memory usage: 93.4 KB

# %%
data.describe() # Statisctics information of dataset
# Out:
#                V1          V3          V4          V5          V6          V7  \
# count  351.000000  351.000000  351.000000  351.000000  351.000000  351.000000
# mean     0.891738    0.641342    0.044372    0.601068    0.115889    0.550095
# std      0.311155    0.497708    0.441435    0.519862    0.460810    0.492654
# min      0.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      1.000000    0.472135   -0.064735    0.412660   -0.024795    0.211310
# 50%      1.000000    0.871110    0.016310    0.809200    0.022800    0.728730
# 75%      1.000000    1.000000    0.194185    1.000000    0.334655    0.969240
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                V8          V9         V10         V11  ...         V26  \
# count  351.000000  351.000000  351.000000  351.000000  ...  351.000000
# mean     0.119360    0.511848    0.181345    0.476183  ...   -0.071187
# std      0.520750    0.507066    0.483851    0.563496  ...    0.508495
# min     -1.000000   -1.000000   -1.000000   -1.000000  ...   -1.000000
# 25%     -0.054840    0.087110   -0.048075    0.021120  ...   -0.332390
# 50%      0.014710    0.684210    0.018290    0.667980  ...   -0.015050
# 75%      0.445675    0.953240    0.534195    0.957895  ...    0.156765
# max      1.000000    1.000000    1.000000    1.000000  ...    1.000000
#
#               V27         V28         V29         V30         V31         V32  \
# count  351.000000  351.000000  351.000000  351.000000  351.000000  351.000000
# mean     0.541641   -0.069538    0.378445   -0.027907    0.352514   -0.003794
# std      0.516205    0.550025    0.575886    0.507974    0.571483    0.513574
# min     -1.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      0.286435   -0.443165    0.000000   -0.236885    0.000000   -0.242595
# 50%      0.708240   -0.017690    0.496640    0.000000    0.442770    0.000000
# 75%      0.999945    0.153535    0.883465    0.154075    0.857620    0.200120
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               V33         V34       Class
# count  351.000000  351.000000  351.000000
# mean     0.349364    0.014480    0.641026
# std      0.522663    0.468337    0.480384
# min     -1.000000   -1.000000    0.000000
# 25%      0.000000   -0.165350    0.000000
# 50%      0.409560    0.000000    1.000000
# 75%      0.813765    0.171660    1.000000
# max      1.000000    1.000000    1.000000
#
# [8 rows x 34 columns]

# %%
data.isna().sum()         #Checking for missing values
# Out:
# V1       0
# V3       0
# V4       0
# V5       0
# V6       0
# V7       0
# V8       0
# V9       0
# V10      0
# V11      0
# V12      0
# V13      0
# V14      0
# V15      0
# V16      0
# V17      0
# V18      0
# V19      0
# V20      0
# V21      0
# V22      0
# V23      0
# V24      0
# V25      0
# V26      0
# V27      0
# V28      0
# V29      0
# V30      0
# V8    -0.139725  0.078585 -0.166682  0.152381 -0.200860  0.360610  0.207544
# V9     0.329813 -0.031983  0.316021 -0.067499  0.344814 -0.095597  0.294852
# V10   -0.123296 -0.008578 -0.155661 -0.015640 -0.203629  0.098104  0.120634
# V11    0.396851  0.074600  0.294646  0.023922  0.339506 -0.152225  0.167908
# V12   -0.208294  0.138842 -0.208855  0.010276 -0.181166  0.066584  0.159940
# V13    0.277995  0.094400  0.355473 -0.041629  0.473780 -0.065131  0.181682
# V14   -0.215050  0.095677 -0.147949 -0.067790 -0.096091  0.096444  0.197041
# V15    0.355917  0.090009  0.445175 -0.013132  0.490879 -0.119929  0.207201
# V16   -0.159639  0.146052 -0.183578  0.101401 -0.179906  0.241702  0.148775
# V17    0.404276  0.074604  0.358692  0.015888  0.360039 -0.063429  0.087060
# V18   -0.118047  0.067712 -0.158096  0.256970 -0.059076  0.054113  0.119346
# V19    0.473187  0.085579  0.418580  0.124713  0.446093  0.001458  0.117435
# V20   -0.213057  0.396781 -0.305049  0.125374 -0.107816  0.188940  0.035620
# V21    0.479619  0.071592  0.511278  0.121923  0.616620 -0.002596  0.219583
# V22   -0.086614  0.323712 -0.075714  0.207718 -0.090417  0.132848 -0.116385
# V23    0.540443  0.165890  0.538973  0.160531  0.503426  0.049284  0.204361
# V24   -0.167937  0.364626 -0.127822  0.084291 -0.211597  0.094685  0.006193
# V25    0.650908  0.013639  0.516121  0.134478  0.460692  0.111086  0.188185
# V26   -0.113499  0.281075 -0.162707  0.340692 -0.085966  0.221630  0.001541
# V27    0.509070  0.163412  0.376400  0.160318  0.469326  0.082969 -0.111107
# V28    0.042002  0.385475 -0.008136  0.500801 -0.124826  0.376772  0.042756
# V29    1.000000 -0.011000  0.553855  0.055997  0.579684  0.082504  0.250036
# V30   -0.011000  1.000000 -0.163586  0.297085 -0.180566  0.391271 -0.003942
# V31    0.553855 -0.163586  1.000000 -0.028877  0.692408 -0.037579  0.294417
# V32    0.055997  0.297085 -0.028877  1.000000 -0.012998  0.514992 -0.036004
# V33    0.579684 -0.180566  0.692408 -0.012998  1.000000 -0.131840  0.261157
# V34    0.082504  0.391271 -0.037579  0.514992 -0.131840  1.000000 -0.064168
# Class  0.250036 -0.003942  0.294417 -0.036004  0.261157 -0.064168  1.000000
#
# [34 rows x 34 columns]

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data.corr(),cmap='rainbow',annot=True);

# %%
sns.pairplot(data[['V3','V4','V5','V6','Class']],hue='Class',palette='rainbow');

# %%
from sklearn.metrics import RocCurveDisplay
import matplotlib.pyplot as plt
import warnings
import missingno as msno
from pingouin import plot_blandaltman
warnings.filterwarnings('ignore')

# %% [markdown]
# # Visualization of missing values

# %%
msno.bar(data,color='lightblue')
plt.show()

# %%
msno.bar(data,color='lightgreen')
plt.show()

# %% [markdown]
# # Data Visualization:-

# %%
def plot_numerical(var):
    fig, axes = plt.subplots(2,2,figsize=(14,10))
    sns.histplot(x = data[var], ax = axes[0][0],kde = True,bins=20)
    qqplot(data[var], dist='norm',ax = axes[0][1])
    sns.stripplot(x = data.V23,y = data[var], ax = axes[1][0],palette = 'bright')
    sns.barplot(x = data.V20,y = data[var], ax = axes[1][1],palette = 'bright')
    plt.suptitle(var.title())
    plt.show()

# %%
numerical_columns = ['V23','V20','V19','V18','V17','V15','V14','V16','V21','V22','V24']

# %%
from pingouin import qqplot

# %%
plot_numerical(numerical_columns[0])

# %%
plot_numerical(numerical_columns[1])

# %%
plot_numerical(numerical_columns[2])

# %% [markdown]
# # Data Splitting

# %%
X= data.drop('Class',axis=1)
y= data['Class']

# %%
X[:5]
# Out:
#    V1       V3       V4       V5       V6       V7       V8       V9      V10  \
# 0   1  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000  0.03760
# 1   1  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000 -0.04549
# 2   1  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965  0.01198
# 3   1  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000  0.00000
# 4   1  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152 -0.16399
#
#        V11  ...      V25      V26      V27      V28      V29      V30  \
# 0  0.85243  ...  0.56811 -0.51171  0.41078 -0.46168  0.21266 -0.34090
# 1  0.50874  ... -0.20332 -0.26569 -0.20468 -0.18401 -0.19040 -0.11593
# 2  0.73082  ...  0.57528 -0.40220  0.58984 -0.22145  0.43100 -0.17365
# 3  0.00000  ...  1.00000  0.90695  0.51613  1.00000  1.00000 -0.20099
# 4  0.52798  ...  0.03286 -0.65158  0.13290 -0.53206  0.02431 -0.62197
#
#        V31      V32      V33      V34
# 0  0.42267 -0.54487  0.18641 -0.45300
# 1 -0.16626 -0.06288 -0.13738 -0.02447
# 2  0.60436 -0.24180  0.56045 -0.38238
# 3  0.25682  1.00000 -0.32382  1.00000
# 4 -0.05707 -0.59573 -0.04608 -0.65697
#
# [5 rows x 33 columns]

# %%
y[:5]
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Class, dtype: int64

# %% [markdown]
# # Modelling Dataset:-

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=25,stratify=y)

# %%
models={'LogisticRegression':LogisticRegression(),
        'DecisionTree': DecisionTreeClassifier(),
        'Random_foresest': RandomForestClassifier(),
        'K-Nearest': KNeighborsClassifier(n_neighbors=3),
        'Gaussian': GaussianNB(),
        'SVM': SVC(),
        'Xgboost': XGBClassifier(),
        'Adaboost': AdaBoostClassifier()}

# %%
model_test_score={}
model_train_score={}

for name,model in models.items():
    model.fit(X_train,y_train)
    model_test_score[name]=model.score(X_test,y_test)
    model_train_score[name]=model.score(X_train,y_train)

# %%
df= pd.DataFrame(model_test_score,index=['Test_accuracy'])
df=df.transpose()

# %%
df['Train_accuracy']=model_train_score.values()
df['Difference']= (df['Train_accuracy']-df['Test_accuracy'])
df
# Out:
#                     Test_accuracy  Train_accuracy  Difference
# LogisticRegression       0.915493        0.910714   -0.004779
# DecisionTree             0.929577        1.000000    0.070423
# Random_foresest          0.957746        1.000000    0.042254
# K-Nearest                0.901408        0.900000   -0.001408
# Gaussian                 0.915493        0.885714   -0.029779
# SVM                      0.971831        0.957143   -0.014688
# Xgboost                  0.957746        1.000000    0.042254
# Adaboost                 0.957746        0.978571    0.020825

# %%
df.plot.bar();

# %% [markdown]
# # using Cross_validation for Logistic Regression

# %%
lr= LogisticRegression()

# %%
# using Accuracy metric
cv_acc= cross_val_score(lr,X,y,cv=10,scoring='accuracy')

# %%
cv_acc=np.mean(cv_acc)
cv_acc
# Out:
# np.float64(0.8604761904761906)

# %%
# using Precision
cv_pre= cross_val_score(lr,X,y,scoring='precision')
cv_pre= np.mean(cv_pre)
cv_pre
# Out:
# np.float64(0.8342638915595678)

# %%
# using Recall
cv_recall= cross_val_score(lr,X,y,scoring='recall')
cv_recall=np.mean(cv_recall)
cv_recall
# Out:
# np.float64(0.9644444444444444)

# %%
#using F1 score
cv_f1= cross_val_score(lr,X,y,scoring='f1')
cv_f1=np.mean(cv_f1)
cv_f1
# Out:
# np.float64(0.8938360872467017)

# %%
cv_metric= {'Accuracy': cv_acc,
           'Precision': cv_pre,
           'Recall': cv_recall,
           'F1': cv_f1}

cv_metric
# Out:
# {'Accuracy': np.float64(0.8604761904761906),
#  'Precision': np.float64(0.8342638915595678),
#  'Recall': np.float64(0.9644444444444444),
#  'F1': np.float64(0.8938360872467017)}

# %%
df_2= pd.DataFrame(cv_metric,index=['Result'])
df_2=df_2.T

# %%
df_2.plot.bar();

# %% [markdown]
# # ploting Roc And Auc Curve

# %%
lr= LogisticRegression().fit(X_train,y_train)

# %%
y_pred= lr.predict(X_test)
y_prob= lr.predict_proba(X_test)

# %%
y_prob
# Out:
# array([[0.06845427, 0.93154573],
#        [0.12570853, 0.87429147],
#        [0.27652601, 0.72347399],
#        [0.90828616, 0.09171384],
#        [0.06455161, 0.93544839],
#        [0.13747968, 0.86252032],
#        [0.98737751, 0.01262249],
#        [0.07334311, 0.92665689],
#        [0.12998513, 0.87001487],
#        [0.08733067, 0.91266933],
#        [0.29509038, 0.70490962],
#        [0.19297643, 0.80702357],
#        [0.14379648, 0.85620352],
#        [0.21011096, 0.78988904],
#        [0.03234666, 0.96765334],
#        [0.93874585, 0.06125415],
#        [0.03556231, 0.96443769],
#        [0.97241582, 0.02758418],
#        [0.0953758 , 0.9046242 ],
#        [0.99242858, 0.00757142],
#        [0.97153857, 0.02846143],
#        [0.09911394, 0.90088606],
#        [0.1103438 , 0.8896562 ],
#        [0.0934853 , 0.9065147 ],
#        [0.08832047, 0.91167953],
#        [0.38588783, 0.61411217],
#        [0.96668781, 0.03331219],
#        [0.89892502, 0.10107498],
#        [0.06160105, 0.93839895],
#        [0.95938245, 0.04061755],
#        [0.25826869, 0.74173131],
#        [0.96374516, 0.03625484],
#        [0.16341353, 0.83658647],
#        [0.20218329, 0.79781671],
#        [0.11958673, 0.88041327],
#        [0.02751614, 0.97248386],
#        [0.05272338, 0.94727662],
#        [0.91747672, 0.08252328],
#        [0.27616311, 0.72383689],
#        [0.08289388, 0.91710612],
#        [0.06403695, 0.93596305],
#        [0.02072481, 0.97927519],
#        [0.06367726, 0.93632274],
#        [0.71108344, 0.28891656],
#        [0.48450898, 0.51549102],
#        [0.12185499, 0.87814501],
#        [0.06432557, 0.93567443],
#        [0.02658233, 0.97341767],
#        [0.64392292, 0.35607708],
#        [0.96860415, 0.03139585],
#        [0.88031391, 0.11968609],
#        [0.98603936, 0.01396064],
#        [0.4807451 , 0.5192549 ],
#        [0.13834764, 0.86165236],
#        [0.07503102, 0.92496898],
#        [0.06565501, 0.93434499],
#        [0.99601887, 0.00398113],
#        [0.08239358, 0.91760642],
#        [0.17112713, 0.82887287],
#        [0.06408328, 0.93591672],
#        [0.88237065, 0.11762935],
#        [0.75565445, 0.24434555],
#        [0.69014165, 0.30985835],
#        [0.87095102, 0.12904898],
#        [0.99553968, 0.00446032],
#        [0.8868065 , 0.1131935 ],
#        [0.20940676, 0.79059324],
#        [0.02816039, 0.97183961],
#        [0.00216414, 0.99783586],
#        [0.01982599, 0.98017401],
#        [0.01825102, 0.98174898]])

# %%
positive_prob=y_prob[:,1]
fpr,tpr,threshold= roc_curve(y_test,positive_prob)
roc_auc= auc(fpr,tpr)
plt.title('Recevier Operating Characteristic')
plt.plot(fpr,tpr,'orange',label='AUC=%0.2f' % roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--')
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate');

# %%
print(roc_auc)
# Out:
# 0.928695652173913

# %%
print(confusion_matrix(y_test,y_pred))
print('\n')
print(classification_report(y_test,y_pred))
# Out:
# [[21  4]
#  [ 2 44]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.88        25
#            1       0.92      0.96      0.94        46
#
#     accuracy                           0.92        71
#    macro avg       0.91      0.90      0.91        71
# weighted avg       0.92      0.92      0.91        71

# %%
pred_data= pd.DataFrame()
pred_data['Y_true']= y_test.values
pred_data['Y_pred']= y_pred

# %% [markdown]
# # ROC Curve

# %%
y_prob= lr.predict_proba(X_test)
fig, ax = plt.subplots(figsize=(10, 6))
RocCurveDisplay.from_predictions(y_test, y_prob[:,1],ax=ax)
ax.set_title("ROC Curve", fontsize=14)
plt.show()

# %% [markdown]
# # Precision Recall Curve

# %%
from sklearn.metrics import PrecisionRecallDisplay
fig, ax = plt.subplots(figsize=(10, 6))
PrecisionRecallDisplay.from_predictions(y_test, y_prob[:,1],ax=ax)
ax.set_title("Precision-Recall Curve", fontsize=14)
plt.show()

# %% [markdown]
# # Learning Curve

# %%
from sklearn.model_selection import LearningCurveDisplay
fig, ax = plt.subplots(figsize=(10, 6))
LearningCurveDisplay.from_estimator(estimator=lr, X=X,y=y,ax=ax)
ax.set_title("Learning Curve", fontsize=14)
plt.show()

# %% [markdown]
# # Lift Curve

# %%
import scikitplot as skplt

# %%
skplt.metrics.plot_lift_curve(y_test, y_prob,figsize=(10,6),title_fontsize=14,text_fontsize=12)  
plt.show()

# %% [markdown]
# # Cumulative Gains Curve

# %%
skplt.metrics.plot_cumulative_gain(y_test, y_prob,figsize=(10,6),title_fontsize=14,text_fontsize=12)
plt.show()

# %% [markdown]
# # Conclusion:-
# The given dataset have target varibale and it is a type of binary class (0,1) its a Supervised machine learning task,after performing varius supervised machine learning models, i found Logistic Regression is most suitable model. hence Logistic Regression is implimented the Area under the curve is given by this model is 93%.

# %% [markdown]
# # THANK YOU
