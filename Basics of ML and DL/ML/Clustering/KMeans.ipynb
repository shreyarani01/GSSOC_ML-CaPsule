# %%
import seaborn as sns
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(
    n_samples=1000,
    n_features=2,
    centers=4,
    random_state=42
)

# %%
# Visualize
sns.scatterplot(x=X[:, 0], y=X[:, 1])
# Out:
# <Axes: >

# %%
# K-Means Clustering
from sklearn.cluster import KMeans

# %%
K = 4

kmeans = KMeans(
    n_clusters=K,
    random_state=42
)

# %%
labels = kmeans.fit_predict(X)
# label = cluster number

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], c=labels)
# Out:
# <Axes: >

# %% [markdown]
# ### Choose our K value - elbow; silhouette score

# %%
# Elbow Method

wcss = []
for k in range(1, 21):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit_predict(X)
    wcss.append(kmeans.inertia_)

# %%
sns.lineplot(x=range(1, 21), y=wcss, marker='o')
# Out:
# <Axes: >

# %%
# Kneed Module

# !pip install kneed
# Out:
# Requirement already satisfied: kneed in c:\users\admin\appdata\local\programs\python\python314\lib\site-packages (0.8.6)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\admin\appdata\local\programs\python\python314\lib\site-packages (from kneed) (2.4.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\admin\appdata\local\programs\python\python314\lib\site-packages (from kneed) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from kneed import KneeLocator

# %%
knee = KneeLocator(range(1, 21), wcss, curve="convex", direction="decreasing")

# %%
print("optimal K = ", knee.elbow)
# Out:
# optimal K =  4

# %% [markdown]
# ### Silhouette Score

# %%
from sklearn.metrics import silhouette_score

# %%
ss = []

for k in range(2, 21):
    kmeans = KMeans(n_clusters=k)
    labels = kmeans.fit_predict(X)
    score = silhouette_score(X, labels)

    ss.append(score)

# %%
# plot - K & ss

sns.lineplot(x=range(2, 21), y=ss, marker='o')
# Out:
# <Axes: >
